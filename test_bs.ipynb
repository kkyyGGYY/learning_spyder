# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
content = requests.get('https://www.qiushibaike.com/text/', headers=headers).text
# print(content.text)
soup = BeautifulSoup(content, 'lxml')
# print(soup.select('#content .content span'))
for span in soup.select('#content .content span'):
    print(span.get_text().strip())
# for i, story in enumerate(soup.select('content div #content-left div .content')):
#     print(story)
# Out:
# 听过最后悔的一首歌大概就是痴心绝对了，里面不是有一句：想用一杯LATTE把你灌醉。记得第一次去吃牛排是请女神去的，特地选了个高档西餐厅，点好牛排后服务员问要喝什么红酒吗？我红酒都没喝过哪知道什么牌子啊！灵光一闪就想到了这句歌词，但英文不好怕发音错误让女神见笑，就对服务员说哦，来瓶那个拉什么的。好在服务员熟悉业务，马上说拉菲是吗先生？我赶紧说对，就是拉菲。谁知服务员又问，您要几几年的呢？要不怎么说我聪明呢？我一听既然问了要哪年的，肯定不能说今年啊，那会丢脸嘛，也不能说随便吧！那就暴露了我没喝过红酒
# …
# 查看全文
# 刚在外面吃饭，旁边桌的哥们突然大叫：“卧槽老板，你快看，你家的碗自己在餐盘里面跑起来了！”我转身一看，嘿，真的，那哥们盛米饭的碗在餐盘里自己移  动呢。这时，周围的食客纷纷掏出手机拍摄起来。一起激动的见证这灵异的一刻。“小伙子，餐盘里有油，身后的风扇开的太大了！有什么大惊小怪的”保洁阿姨一脸不屑的说。
# 朋友养了一只哈士奇，特别能拆家，尤其茶几已经拆了好几个了，朋友一狠心花了大几百换了一个大理石茶几。结果狗狗牙崩了，治疗花了好两千多！
# 昨晚相亲，对方妹子挺文静的，话不多还一直微笑，带她去吃火锅，人多拿了号排队。可当她发现有人插队后，立马就像换了个人似的，我说算了，妹子大吼，让我闭嘴……
# 每天额娘叫我起床都叫不起来，但是最后我终于发现额娘非常十分之歹毒――断我wifi！害我不得不起来插上wifi
# 单位一位女同事工作非常努力，业绩也很好～～～一天我问她这么多年坚持下来的秘诀是什么？女同事说：“每当感觉累的时候就摸摸自己的胸，告诉自己是男的，要坚强……”
# 今天得知一同学在住院，得阑尾炎，遥想当年我被狗咬，打完针医生说要戒口，那段时间天天清淡，他经常在我面前又是火锅又是麻辣烫，撸烤串什么的馋我，今天可算得到机会了。在糗百选了两天的搞笑帖子，在他面前聊天时不时说一个，看着他捂着伤口，表情痛苦，嘴巴却还是哈哈大笑，完全一副痛并快乐着的模样我心里舒坦多了……
# 早上把娃送进学校，打开车门做到后座，打开糗百，老半天车子也不走，才反应过来，特么我是司机，
# 如果不说以前做过押款员，脚受伤了我说是拿钱砸的你们会信吗？
# 总是遇见一个人，是不是就是缘分，我老是遇见有个胖子从我身体走出，可一晃眼看见它还是如影随形
# ...
